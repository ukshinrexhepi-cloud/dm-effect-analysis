# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ukshinrexhepi-cloud/dm-effect-analysis.git
# Out:
# fatal: destination path 'dm-effect-analysis' already exists and is not an empty directory.

# %%
# %cd dm-effect-analysis
# Out:
# /content/dm-effect-analysis

# %%
import os
os.listdir()
# Out:
# ['.git',
#  'notebook',
#  'figures',
#  'plots',
#  'README.md',
#  'requirements.txt',
#  'data',
#  '.gitignore',
#  'paper',
#  'docs']

# %%
os.listdir("data/btfr")
# Out:
# ['.gitkeep', 'merged_btfr.csv', 'clean_btfr.csv']

# %%
import pandas as pd

merged = pd.read_csv("data/btfr/merged_btfr.csv")
clean  = pd.read_csv("data/btfr/clean_btfr.csv")

print(len(clean))
# Out:
# 105

# %%
# !pip install -r requirements.txt

# %%
# OPTIONAL: recreate merged dataset
"""
merged = pd.merge(
    vflat_df,
    sparc_df,
    left_on="galaxy",
    right_on="Galaxy",
    how="inner"
)
"""
